# %% [markdown]
# <a href="https://colab.research.google.com/github/nullvoid-ky/introduction-to-machine-learning-and-deep-learning/blob/main/last/02_DT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install kagglehub numpy pandas seaborn matplotlib scikit-learn imbalanced-learn "ray[tune]"
# Import stuff
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import SMOTE

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.preprocessing import label_binarize
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.0)
# Collecting ray[tune]
#   Downloading ray-2.50.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Collecting click!=8.3.0,>=7.0 (from ray[tune])
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (3.20.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (4.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (1.1.2)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (5.29.5)
# Collecting tensorboardX>=1.9 (from ray[tune])
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (18.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from ray[tune]) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray[tune]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray[tune]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray[tune]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray[tune]) (0.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2025.10.5)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema->ray[tune]) (4.15.0)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 4.3 MB/s eta 0:00:00
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.3 MB/s eta 0:00:00
# Downloading ray-2.50.0-cp312-cp312-manylinux2014_x86_64.whl (71.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 MB 10.5 MB/s eta 0:00:00
# Installing collected packages: tensorboardX, click, ray
#   Attempting uninstall: click
#     Found existing installation: click 8.3.0
#     Uninstalling click-8.3.0:
#       Successfully uninstalled click-8.3.0
# Successfully installed click-8.2.1 ray-2.50.0 tensorboardX-2.6.4

# %%
# @title DT
class DecisionNode:
  def __init__(self, impurity=None, feature_index=None, threshold=None, left=None, right=None):
    self.left = left
    self.right = right
    # The largest impurity value of this node
    self.impurity = impurity
    # Index of the feature which make the best fit for this node.
    self.feature_index = feature_index
    # The threshold value for that feature to make the split.
    self.threshold = threshold

class LeafNode:
  def __init__(self, value):
    self.prediction_value = value

class DecisionTreeClassifierFromScratch(BaseEstimator, ClassifierMixin):
  def __init__(self, min_sample_split=3, min_impurity=1e-7, max_depth=10, criterion='gini'):
    self.root = None
    self.min_sample_split = min_sample_split
    self.min_impurity = min_impurity
    self.max_depth = max_depth
    self.impurity_function = self._calculate_information_gain
    if criterion == 'entropy':
      self.criterion = self._entropy
      self.criterion_name = criterion
    else:
      self.criterion = self._gini_index
      self.criterion_name = 'gini'

  def _gini_index(self, y):
    gini = 1
    unique_value = np.unique(y)
    for val in unique_value:
      # probability of that class.
      p = np.sum(y == val) / len(y)
      gini += -np.square(p)
    return gini

  def _entropy(self, y):
    entropy = 0
    unique_value = np.unique(y)
    for val in unique_value:
      # probability of that class.
      p = np.sum(y == val) / len(y)
      entropy += -p * np.log2(p)
    return entropy

  def _calculate_information_gain(self, y, y1, y2):
    # :param y: target value.
    # :param y1: target value for dataset in the true split/right branch.
    # :param y2: target value for dataset in the false split/left branch.

    # propobility of true values.
    p = len(y1) / len(y)
    info_gain = self.criterion(y) - p * self.criterion(y1) - (1 - p) * self.criterion(y2)
    return info_gain

  def _leaf_value_calculation(self, y):
    most_frequent_label = None
    max_count = 0
    unique_labels = np.unique(y)
    # iterate over all the unique values and find their frequentcy count.
    for label in unique_labels:
      count = len( y[y == label])
      if count > max_count:
        most_frequent_label = label
        max_count = count
    return most_frequent_label

  def _partition_dataset(self, Xy, feature_index, threshold):
    col = Xy[:, feature_index]
    X_1 = Xy[col >= threshold]
    X_2 = Xy[col < threshold]

    return X_1, X_2

  def _find_best_split(self, Xy):
    best_question = tuple()
    best_datasplit = {}
    largest_impurity = 0
    n_features = (Xy.shape[1] - 1)
    # iterate over all the features.
    for feature_index in range(n_features):
      # find the unique values in that feature.
      unique_value = set(s for s in Xy[:,feature_index])
      # iterate over all the unique values to find the impurity.
      for threshold in unique_value:
        # split the dataset based on the feature value.
        true_xy, false_xy = self._partition_dataset(Xy, feature_index, threshold)

        # skip the node which has any on type 0. because this means it is already pure.
        if len(true_xy) > 0 and len(false_xy) > 0:
          # find the y values.
          y = Xy[:, -1]
          true_y = true_xy[:, -1]
          false_y = false_xy[:, -1]
          # calculate the impurity function.
          impurity = self.impurity_function(y, true_y, false_y)

          # if the calculated impurity is larger than save this value for comaparison (highest gain).
          if impurity > largest_impurity:
            largest_impurity = impurity
            best_question = (feature_index, threshold)
            best_datasplit = {
              "leftX": true_xy[:, :n_features],   # X of left subtree
              "lefty": true_xy[:, n_features:],   # y of left subtree
              "rightX": false_xy[:, :n_features],  # X of right subtree
              "righty": false_xy[:, n_features:]   # y of right subtree
            }

    return largest_impurity, best_question, best_datasplit

  def _build_tree(self, X, y, current_depth=0):
    n_samples , n_features = X.shape
    # Add y as last column of X
    Xy = np.column_stack((X, y))
    # find the Information gain on each feature each values and return the question which splits the data very well
    if (n_samples >= self.min_sample_split) and (current_depth < self.max_depth):
      # find the best split/ which question split the data well.
      impurity, question, best_datasplit = self._find_best_split(Xy)
      if impurity > self.min_impurity:
        # Build subtrees for the right and left branch.
        true_branch = self._build_tree(best_datasplit["leftX"], best_datasplit["lefty"], current_depth + 1)
        false_branch = self._build_tree(best_datasplit["rightX"], best_datasplit["righty"], current_depth + 1)
        return DecisionNode(impurity=impurity, feature_index=question[0], threshold=question[1],
                            left=true_branch, right=false_branch)

    leaf_value = self._leaf_value_calculation(y)
    return LeafNode(value=leaf_value)

  def fit(self, X, y):
    self.root = self._build_tree(X, y, current_depth=0)

  def predict_sample(self, x, tree=None):
    if isinstance(tree , LeafNode):
      return tree.prediction_value

    if tree is None:
      tree = self.root
    feature_value = x[tree.feature_index]
    branch = tree.right

    if isinstance(feature_value, int) or isinstance(feature_value, float):
      if feature_value >= tree.threshold:
        branch = tree.left
    elif feature_value == tree.threshold:
      branch = tree.left

    return self.predict_sample(x, branch)

  def predict(self, test_X):
    x = np.array(test_X)
    y_pred = [self.predict_sample(sample) for sample in x]
    y_pred = np.array(y_pred)
    return y_pred

  def draw_tree(self):
    self._draw_tree(self.root)

  def _draw_tree(self, tree = None, indentation = " ", depth=0):
    if isinstance(tree , LeafNode):
      print(indentation,"The predicted value -->", tree.prediction_value)
      return
    else:
      print(indentation,f"({depth}) Is {tree.feature_index}>={tree.threshold}?"
            f": {self.criterion_name}:{tree.impurity:.2f}")
      if tree.left is not None:
          print (indentation + '----- True branch :)')
          self._draw_tree(tree.left, indentation + "  ", depth+1)
      if tree.right is not None:
          print (indentation + '----- False branch :)')
          self._draw_tree(tree.right, indentation + "  ", depth+1)

  def predict_proba(self, X):
    X = np.array(X)
    probs = []
    for sample in X:
        node = self.root
        while not isinstance(node, LeafNode):
            feature_value = sample[node.feature_index]
            if feature_value >= node.threshold:
                node = node.left
            else:
                node = node.right
        # compute class probability in this leaf node
        y_leaf = node.prediction_value
        # If you only stored a single class, just make it binary
        if y_leaf == 1:
            probs.append(1.0)
        else:
            probs.append(0.0)
    return np.array(probs)

# %%
import kagglehub
path = kagglehub.dataset_download("utkarshx27/american-companies-bankruptcy-prediction-dataset")

print("Path to dataset files:", path)

file_path = "/root/.cache/kagglehub/datasets/utkarshx27/american-companies-bankruptcy-prediction-dataset/versions/3/american_bankruptcy.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/utkarshx27/american-companies-bankruptcy-prediction-dataset?dataset_version_number=3...
# 100%|██████████| 4.47M/4.47M [00:00<00:00, 93.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/utkarshx27/american-companies-bankruptcy-prediction-dataset/versions/3
#   company_name status_label  year       X1       X2      X3      X4       X5  \
# 0          C_1        alive  1999  511.267  833.107  18.373  89.031  336.018
# 1          C_1        alive  2000  485.856  713.811  18.577  64.367  320.590
# 2          C_1        alive  2001  436.656  526.477  22.496  27.207  286.588
# 3          C_1        alive  2002  396.412  496.747  27.172  30.745  259.954
# 4          C_1        alive  2003  432.204  523.302  26.680  47.491  247.245
#
#        X6       X7  ...        X9      X10      X11     X12      X13      X14  \
# 0  35.163  128.348  ...  1024.333  740.998  180.447  70.658  191.226  163.816
# 1  18.531  115.187  ...   874.255  701.854  179.987  45.790  160.444  125.392
# 2 -58.939   77.528  ...   638.721  710.199  217.699   4.711  112.244  150.464
# 3 -12.410   66.322  ...   606.337  686.621  164.658   3.573  109.590  203.575
# 4   3.504  104.661  ...   651.958  709.292  248.666  20.811  128.656  131.261
#
#        X15       X16      X17      X18
# 0  201.026  1024.333  401.483  935.302
# 1  204.065   874.255  361.642  809.888
# 2  139.603   638.721  399.964  611.514
# 3  124.106   606.337  391.633  575.592
# 4  131.884   651.958  407.608  604.467
#
# [5 rows x 21 columns]

# %%
df_unique = df.groupby("company_name", group_keys=False).apply(lambda x: x.sample(n=1))
# Out:
# /tmp/ipython-input-2508231616.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_unique = df.groupby("company_name", group_keys=False).apply(lambda x: x.sample(n=1))

# %%
df
# Out:
#       company_name status_label  year       X1       X2      X3       X4  \
# 0              C_1        alive  1999  511.267  833.107  18.373   89.031
# 1              C_1        alive  2000  485.856  713.811  18.577   64.367
# 2              C_1        alive  2001  436.656  526.477  22.496   27.207
# 3              C_1        alive  2002  396.412  496.747  27.172   30.745
# 4              C_1        alive  2003  432.204  523.302  26.680   47.491
# ...            ...          ...   ...      ...      ...     ...      ...
# 78677       C_8971        alive  2014  233.211   43.338  14.094   45.615
# 78678       C_8971        alive  2015  105.559   59.184  42.592  202.133
# 78679       C_8971        alive  2016   63.971   69.074  65.057   79.051
# 78680       C_8971        alive  2017  135.207   66.527  65.330   69.171
# 78681       C_8971        alive  2018   82.589   68.817  65.201   67.262
#
#             X5       X6       X7  ...        X9       X10      X11      X12  \
# 0      336.018   35.163  128.348  ...  1024.333   740.998  180.447   70.658
# 1      320.590   18.531  115.187  ...   874.255   701.854  179.987   45.790
# 2      286.588  -58.939   77.528  ...   638.721   710.199  217.699    4.711
# 3      259.954  -12.410   66.322  ...   606.337   686.621  164.658    3.573
# 4      247.245    3.504  104.661  ...   651.958   709.292  248.666   20.811
# ...        ...      ...      ...  ...       ...       ...      ...      ...
# 78677    3.376   25.261   22.846  ...   104.223  1099.101  184.666   31.521
# 78678    2.288  129.688   54.611  ...   291.153  1865.926  770.103  159.541
# 78679    2.581   -1.442   42.467  ...   169.858  1746.235  683.985   13.994
# 78680    2.013  -20.401   27.217  ...   161.884  1736.110  694.035    3.841
# 78681    2.112  -50.946   45.839  ...   160.513  1625.370  632.122    2.061
#
#            X13      X14      X15       X16      X17      X18
# 0      191.226  163.816  201.026  1024.333  401.483  935.302
# 1      160.444  125.392  204.065   874.255  361.642  809.888
# 2      112.244  150.464  139.603   638.721  399.964  611.514
# 3      109.590  203.575  124.106   606.337  391.633  575.592
# 4      128.656  131.261  131.884   651.958  407.608  604.467
# ...        ...      ...      ...       ...      ...      ...
# 78677   60.885   28.197   28.095   104.223  225.887   58.608
# 78678  231.969   88.128  157.783   291.153  880.327   89.020
# 78679  100.784   85.765  156.341   169.858  770.233   90.807
# 78680   95.357   82.010  135.941   161.884  776.697   92.713
# 78681   91.696   79.365   84.995   160.513  712.687   93.251
#
# [78682 rows x 21 columns]

# %%
df_unique
# Out:
#       company_name status_label  year         X1          X2        X3  \
# 18             C_1        alive  2017    942.700    1413.200    40.500
# 128           C_10        alive  2017   1016.288    2096.751   534.118
# 1202         C_100        alive  2003     20.422       9.668     4.282
# 11944       C_1000        alive  2017   4324.000    1713.000   180.000
# 11957       C_1001        alive  2010  22357.000  105938.000   271.000
# ...            ...          ...   ...        ...         ...       ...
# 11857        C_995        alive  2000   1076.559    2955.617   146.214
# 11864        C_996        alive  2000     82.052     115.784     3.425
# 11878        C_997        alive  2011   1222.900    2089.300    85.800
# 11900        C_998       failed  2013   1080.200    2716.846    84.580
# 11925        C_999        alive  2018   4053.200    8936.300  1302.900
#
#              X4        X5        X6        X7  ...          X9        X10  \
# 18      126.500   547.900    15.600   203.000  ...    1748.300   1524.700
# 128    1468.545   289.270   488.456   415.068  ...    3565.296  17019.082
# 1202     12.949     0.143    12.429     2.633  ...      26.603     92.116
# 11944  2939.000     0.000  1496.000  1319.000  ...    6063.000   9425.000
# 11957  2369.000  9225.000  1202.000  9187.000  ...  112084.000  30886.000
# ...         ...       ...       ...       ...  ...         ...        ...
# 11857   613.684   408.550   200.967   538.403  ...    4247.504   2668.924
# 11864     7.331    52.031    -0.086    28.381  ...     141.118    123.685
# 11878   637.000   613.700   374.200   427.000  ...    3697.600   4087.800
# 11900  -259.085   425.986  -516.913   471.131  ...    2658.932   2807.371
# 11925  9888.700    51.100  5924.300  2441.500  ...   21025.200  32811.200
#
#              X11       X12        X13        X14        X15         X16  \
# 18       177.200    86.000    335.100    333.300    701.200    1748.300
# 128     4789.713   934.427   1468.545   1197.852   2397.509    3565.296
# 1202       0.000     8.667     16.935      4.837     76.871      26.603
# 11944   3170.000  2759.000   4350.000   3214.000   9376.000    6063.000
# 11957   3587.000  2098.000   6146.000  18726.000   8347.000  112084.000
# ...          ...       ...        ...        ...        ...         ...
# 11857    451.336   467.470   1291.887    971.687   1159.964    4247.504
# 11864     67.476     3.906     25.334     22.464     25.933     141.118
# 11878   1029.700   551.200   1608.300    993.300    779.800    3697.600
# 11900     49.019  -343.665    -57.914   1120.984   -211.288    2658.932
# 11925  31075.300  8585.800  12088.900   2973.500  47877.500   21025.200
#
#              X17         X18
# 18       588.400    1621.800
# 128    11883.352    2096.751
# 1202       5.845      13.654
# 11944   7307.000    3124.000
# 11957  23666.000  109715.000
# ...          ...         ...
# 11857   2082.185    3633.820
# 11864     93.478     133.787
# 11878   2469.300    3060.600
# 11900   1367.027    2918.017
# 11925  39069.600   11136.500
#
# [8971 rows x 21 columns]

# %%
X = df_unique[
    ["X8", "X17", "X3", "X11", "X15", "X1", "X6"]
]
y = df_unique["status_label"].map({"alive": 0, "failed": 1})

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.35, random_state=42
)

# %%
alive_count = (y_train == 0).sum()
failed_count = (y_train == 1).sum()

print(f"Alive: {alive_count}\nBankruptcy: {failed_count}")
# Out:
# Alive: 5448
# Bankruptcy: 383

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
sm = SMOTE(random_state=42, k_neighbors=3)
X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
alive_count = (y_train == 0).sum()
failed_count = (y_train == 1).sum()

print(f"Alive: {alive_count}\nBankruptcy: {failed_count}")
# Out:
# Alive: 5448
# Bankruptcy: 5448

# %%
# Grid Search
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
params = {
    "max_depth": [3, 5, 10, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "criterion": ["gini", "entropy"],
}

# Define the Decision Tree model
model = DecisionTreeClassifier()

grid_dt = GridSearchCV(model, params, cv=4, scoring="f1")
grid_dt.fit(X_train, y_train)
print("Best parameters:\n", grid_dt.best_params_)
print("Best score:", grid_dt.best_score_)
# Out:
# Best parameters:
#  {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best score: 0.8468560517207231

# %%
criterion = "entropy"
max_depth= None
min_samples_leaf = 1
min_samples_split= 2

# %%
tree = DecisionTreeClassifierFromScratch(
    max_depth=20,
    criterion=criterion,
    # min_samples_leaf=min_samples_leaf,
    min_sample_split=min_samples_split,
)
tree.fit(X_train, y_train)
y_pred = tree.predict(X_test)
tree.draw_tree()
# Out:
#   (0) Is 3>=6.206468111102405e-05?: entropy:0.06
#  ----- True branch :)
#     (1) Is 6>=182.917?: entropy:0.02
#    ----- True branch :)
#       (2) Is 0>=22179.1982?: entropy:0.07
#      ----- True branch :)
#         The predicted value --> 0.0
#      ----- False branch :)
#         (3) Is 4>=309.9244029099086?: entropy:0.07
#        ----- True branch :)
#           (4) Is 2>=99.052146496005?: entropy:0.06
#          ----- True branch :)
#             (5) Is 5>=242.31?: entropy:0.07
#            ----- True branch :)
#               (6) Is 4>=4684.0?: entropy:0.06
#              ----- True branch :)
#                 The predicted value --> 0.0
#              ----- False branch :)
#                 (7) Is 5>=11310.059786061418?: entropy:0.06
#                ----- True branch :)
#                   The predicted value --> 1.0
#                ----- False branch :)
#                   (8) Is 4>=716.2267691209556?: entropy:0.05
#                  ----- True branch :)
#                     (9) Is 0>=7555.54?: entropy:0.06
#                    ----- True branch :)
#                       (10) Is 4>=2871.457467191744?: entropy:0.14
#                      ----- True branch :)
#                         (11) Is 2>=368.5448901272872?: entropy:0.29
#                        ----- True branch :)
#                           (12) Is 1>=12707.193700488697?: entropy:0.12
#                          ----- True branch :)
#                             (13) Is 4>=3549.654?: entropy:0.45
#                            ----- True branch :)
#                               (14) Is 1>=18093.769?: entropy:0.92
#                              ----- True branch :)
#                                 The predicted value --> 0.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                            ----- False branch :)
#                               The predicted value --> 1.0
#                          ----- False branch :)
#                             (13) Is 6>=680.528?: entropy:0.32
#                            ----- True branch :)
#                               The predicted value --> 0.0
#                            ----- False branch :)
#                               (14) Is 5>=2150.0?: entropy:0.42
#                              ----- True branch :)
#                                 (15) Is 6>=291.0?: entropy:0.92
#                                ----- True branch :)
#                                   The predicted value --> 0.0
#                                ----- False branch :)
#                                   The predicted value --> 1.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                        ----- False branch :)
#                           The predicted value --> 0.0
#                      ----- False branch :)
#                         (11) Is 6>=997.6119589613685?: entropy:0.11
#                        ----- True branch :)
#                           (12) Is 0>=9484.7366?: entropy:0.81
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             The predicted value --> 1.0
#                        ----- False branch :)
#                           The predicted value --> 0.0
#                    ----- False branch :)
#                       (10) Is 4>=1437.71?: entropy:0.14
#                      ----- True branch :)
#                         (11) Is 1>=4220.118603399634?: entropy:0.32
#                        ----- True branch :)
#                           (12) Is 2>=419.0?: entropy:0.74
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             (13) Is 2>=363.0?: entropy:0.27
#                            ----- True branch :)
#                               (14) Is 0>=6819.8572896933465?: entropy:1.00
#                              ----- True branch :)
#                                 The predicted value --> 1.0
#                              ----- False branch :)
#                                 The predicted value --> 0.0
#                            ----- False branch :)
#                               The predicted value --> 1.0
#                        ----- False branch :)
#                           The predicted value --> 0.0
#                      ----- False branch :)
#                         (11) Is 0>=3135.596925161829?: entropy:0.23
#                        ----- True branch :)
#                           (12) Is 0>=4683.3928509177?: entropy:0.13
#                          ----- True branch :)
#                             (13) Is 1>=3655.02?: entropy:0.39
#                            ----- True branch :)
#                               The predicted value --> 0.0
#                            ----- False branch :)
#                               The predicted value --> 1.0
#                          ----- False branch :)
#                             (13) Is 1>=4889.39981548627?: entropy:0.63
#                            ----- True branch :)
#                               (14) Is 1>=10058.925?: entropy:0.32
#                              ----- True branch :)
#                                 The predicted value --> 0.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                            ----- False branch :)
#                               (14) Is 2>=120.339?: entropy:0.39
#                              ----- True branch :)
#                                 The predicted value --> 0.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                        ----- False branch :)
#                           The predicted value --> 0.0
#                  ----- False branch :)
#                     The predicted value --> 0.0
#            ----- False branch :)
#               (6) Is 0>=5261.0112?: entropy:0.35
#              ----- True branch :)
#                 The predicted value --> 0.0
#              ----- False branch :)
#                 The predicted value --> 1.0
#          ----- False branch :)
#             (5) Is 1>=274.9?: entropy:0.15
#            ----- True branch :)
#               The predicted value --> 0.0
#            ----- False branch :)
#               The predicted value --> 1.0
#        ----- False branch :)
#           The predicted value --> 0.0
#    ----- False branch :)
#       (2) Is 6>=-5.039?: entropy:0.01
#      ----- True branch :)
#         (3) Is 5>=0.599?: entropy:0.01
#        ----- True branch :)
#           (4) Is 0>=860.13?: entropy:0.01
#          ----- True branch :)
#             (5) Is 5>=858.591?: entropy:0.02
#            ----- True branch :)
#               (6) Is 4>=413.5767362549035?: entropy:0.14
#              ----- True branch :)
#                 (7) Is 1>=877.5833537760523?: entropy:0.09
#                ----- True branch :)
#                   (8) Is 2>=567.2?: entropy:0.07
#                  ----- True branch :)
#                     The predicted value --> 0.0
#                  ----- False branch :)
#                     (9) Is 2>=434.0445792647509?: entropy:0.10
#                    ----- True branch :)
#                       (10) Is 1>=6890.930608857304?: entropy:0.37
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#                    ----- False branch :)
#                       (10) Is 4>=617.4272164522371?: entropy:0.13
#                      ----- True branch :)
#                         (11) Is 0>=1696.8201?: entropy:0.18
#                        ----- True branch :)
#                           (12) Is 3>=2599.826038777387?: entropy:0.19
#                          ----- True branch :)
#                             (13) Is 1>=10367.9?: entropy:0.50
#                            ----- True branch :)
#                               The predicted value --> 0.0
#                            ----- False branch :)
#                               The predicted value --> 1.0
#                          ----- False branch :)
#                             (13) Is 5>=1231.6?: entropy:0.34
#                            ----- True branch :)
#                               The predicted value --> 0.0
#                            ----- False branch :)
#                               (14) Is 2>=68.395?: entropy:0.39
#                              ----- True branch :)
#                                 (15) Is 6>=124.9?: entropy:0.47
#                                ----- True branch :)
#                                   The predicted value --> 0.0
#                                ----- False branch :)
#                                   (16) Is 6>=86.59547082988847?: entropy:0.46
#                                  ----- True branch :)
#                                     The predicted value --> 1.0
#                                  ----- False branch :)
#                                     (17) Is 0>=2409.5036?: entropy:0.92
#                                    ----- True branch :)
#                                       The predicted value --> 0.0
#                                    ----- False branch :)
#                                       The predicted value --> 1.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                        ----- False branch :)
#                           (12) Is 3>=432.8418188016893?: entropy:0.49
#                          ----- True branch :)
#                             The predicted value --> 1.0
#                          ----- False branch :)
#                             The predicted value --> 0.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#                ----- False branch :)
#                   The predicted value --> 0.0
#              ----- False branch :)
#                 (7) Is 2>=155.8593884855889?: entropy:0.12
#                ----- True branch :)
#                   (8) Is 0>=1344.6032?: entropy:0.35
#                  ----- True branch :)
#                     (9) Is 4>=300.3904500007643?: entropy:0.47
#                    ----- True branch :)
#                       The predicted value --> 1.0
#                    ----- False branch :)
#                       The predicted value --> 0.0
#                  ----- False branch :)
#                     The predicted value --> 1.0
#                ----- False branch :)
#                   The predicted value --> 0.0
#            ----- False branch :)
#               (6) Is 0>=1322.0066509522574?: entropy:0.05
#              ----- True branch :)
#                 (7) Is 0>=5051.859?: entropy:0.03
#                ----- True branch :)
#                   The predicted value --> 0.0
#                ----- False branch :)
#                   (8) Is 0>=4396.704?: entropy:0.05
#                  ----- True branch :)
#                     (9) Is 4>=262.93805099092486?: entropy:0.13
#                    ----- True branch :)
#                       (10) Is 2>=197.731?: entropy:0.14
#                      ----- True branch :)
#                         The predicted value --> 0.0
#                      ----- False branch :)
#                         The predicted value --> 1.0
#                    ----- False branch :)
#                       (10) Is 1>=2298.229?: entropy:0.92
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#                  ----- False branch :)
#                     (9) Is 4>=725.33?: entropy:0.06
#                    ----- True branch :)
#                       (10) Is 0>=4298.736214971085?: entropy:0.24
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#                    ----- False branch :)
#                       (10) Is 0>=3608.587?: entropy:0.04
#                      ----- True branch :)
#                         The predicted value --> 0.0
#                      ----- False branch :)
#                         (11) Is 5>=297.552?: entropy:0.03
#                        ----- True branch :)
#                           (12) Is 1>=440.229?: entropy:0.04
#                          ----- True branch :)
#                             (13) Is 2>=205.53980821655844?: entropy:0.08
#                            ----- True branch :)
#                               (14) Is 3>=3012.643?: entropy:0.15
#                              ----- True branch :)
#                                 The predicted value --> 0.0
#                              ----- False branch :)
#                                 (15) Is 4>=-2827.2401155647694?: entropy:0.11
#                                ----- True branch :)
#                                   The predicted value --> 1.0
#                                ----- False branch :)
#                                   (16) Is 0>=3266.5067393163413?: entropy:0.81
#                                  ----- True branch :)
#                                     The predicted value --> 1.0
#                                  ----- False branch :)
#                                     The predicted value --> 0.0
#                            ----- False branch :)
#                               (14) Is 3>=1067.585?: entropy:0.11
#                              ----- True branch :)
#                                 The predicted value --> 0.0
#                              ----- False branch :)
#                                 (15) Is 1>=1525.4910144725009?: entropy:0.12
#                                ----- True branch :)
#                                   (16) Is 1>=2496.962?: entropy:0.19
#                                  ----- True branch :)
#                                     The predicted value --> 0.0
#                                  ----- False branch :)
#                                     (17) Is 2>=73.31575587005123?: entropy:0.13
#                                    ----- True branch :)
#                                       (18) Is 3>=725.5730634761293?: entropy:0.19
#                                      ----- True branch :)
#                                         The predicted value --> 1.0
#                                      ----- False branch :)
#                                         The predicted value --> 0.0
#                                    ----- False branch :)
#                                       The predicted value --> 0.0
#                                ----- False branch :)
#                                   (16) Is 1>=837.903?: entropy:0.22
#                                  ----- True branch :)
#                                     (17) Is 6>=22.0?: entropy:0.18
#                                    ----- True branch :)
#                                       The predicted value --> 0.0
#                                    ----- False branch :)
#                                       (18) Is 3>=603.332?: entropy:0.97
#                                      ----- True branch :)
#                                         The predicted value --> 0.0
#                                      ----- False branch :)
#                                         The predicted value --> 1.0
#                                  ----- False branch :)
#                                     (17) Is 5>=363.665?: entropy:0.30
#                                    ----- True branch :)
#                                       (18) Is 4>=527.355760167153?: entropy:0.26
#                                      ----- True branch :)
#                                         (19) Is 3>=188.42924330573894?: entropy:0.54
#                                        ----- True branch :)
#                                           The predicted value --> 1.0
#                                        ----- False branch :)
#                                           The predicted value --> 0.0
#                                      ----- False branch :)
#                                         (19) Is 4>=83.334?: entropy:0.31
#                                        ----- True branch :)
#                                           The predicted value --> 0.0
#                                        ----- False branch :)
#                                           The predicted value --> 0.0
#                                    ----- False branch :)
#                                       The predicted value --> 1.0
#                          ----- False branch :)
#                             (13) Is 4>=-60.689?: entropy:0.08
#                            ----- True branch :)
#                               (14) Is 4>=46.629?: entropy:0.08
#                              ----- True branch :)
#                                 (15) Is 2>=27.323835819340257?: entropy:0.16
#                                ----- True branch :)
#                                   (16) Is 3>=19.25?: entropy:0.13
#                                  ----- True branch :)
#                                     (17) Is 6>=49.9246456310255?: entropy:0.15
#                                    ----- True branch :)
#                                       (18) Is 6>=75.548?: entropy:0.21
#                                      ----- True branch :)
#                                         (19) Is 4>=605.2536479833932?: entropy:0.39
#                                        ----- True branch :)
#                                           The predicted value --> 1.0
#                                        ----- False branch :)
#                                           The predicted value --> 0.0
#                                      ----- False branch :)
#                                         The predicted value --> 1.0
#                                    ----- False branch :)
#                                       The predicted value --> 0.0
#                                  ----- False branch :)
#                                     The predicted value --> 1.0
#                                ----- False branch :)
#                                   (16) Is 3>=8.604805756485323?: entropy:0.21
#                                  ----- True branch :)
#                                     (17) Is 5>=312.83?: entropy:0.26
#                                    ----- True branch :)
#                                       (18) Is 0>=2467.7672178324783?: entropy:0.41
#                                      ----- True branch :)
#                                         The predicted value --> 1.0
#                                      ----- False branch :)
#                                         (19) Is 4>=77.305?: entropy:0.27
#                                        ----- True branch :)
#                                           The predicted value --> 0.0
#                                        ----- False branch :)
#                                           The predicted value --> 1.0
#                                    ----- False branch :)
#                                       The predicted value --> 1.0
#                                  ----- False branch :)
#                                     The predicted value --> 0.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                            ----- False branch :)
#                               The predicted value --> 0.0
#                        ----- False branch :)
#                           (12) Is 2>=55.213?: entropy:0.43
#                          ----- True branch :)
#                             (13) Is 0>=3122.5771581658187?: entropy:0.20
#                            ----- True branch :)
#                               The predicted value --> 1.0
#                            ----- False branch :)
#                               (14) Is 3>=1038.2203026627362?: entropy:0.30
#                              ----- True branch :)
#                                 (15) Is 0>=2543.268?: entropy:0.34
#                                ----- True branch :)
#                                   The predicted value --> 0.0
#                                ----- False branch :)
#                                   (16) Is 0>=1504.9346553161397?: entropy:0.21
#                                  ----- True branch :)
#                                     The predicted value --> 1.0
#                                  ----- False branch :)
#                                     (17) Is 0>=1436.3133?: entropy:1.00
#                                    ----- True branch :)
#                                       The predicted value --> 0.0
#                                    ----- False branch :)
#                                       The predicted value --> 1.0
#                              ----- False branch :)
#                                 (15) Is 0>=2974.868305206836?: entropy:0.56
#                                ----- True branch :)
#                                   (16) Is 0>=3121.4904?: entropy:0.72
#                                  ----- True branch :)
#                                     The predicted value --> 0.0
#                                  ----- False branch :)
#                                     The predicted value --> 1.0
#                                ----- False branch :)
#                                   The predicted value --> 0.0
#                          ----- False branch :)
#                             The predicted value --> 0.0
#              ----- False branch :)
#                 (7) Is 6>=81.37698672003364?: entropy:0.16
#                ----- True branch :)
#                   (8) Is 4>=430.012?: entropy:0.28
#                  ----- True branch :)
#                     (9) Is 5>=838.4532801039126?: entropy:0.24
#                    ----- True branch :)
#                       (10) Is 0>=1319.260155324616?: entropy:1.00
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#                    ----- False branch :)
#                       The predicted value --> 0.0
#                  ----- False branch :)
#                     (9) Is 1>=854.221?: entropy:0.19
#                    ----- True branch :)
#                       (10) Is 2>=141.12890170708624?: entropy:0.65
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#                    ----- False branch :)
#                       (10) Is 5>=548.4892146692803?: entropy:0.16
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         (11) Is 0>=1150.0?: entropy:0.38
#                        ----- True branch :)
#                           The predicted value --> 0.0
#                        ----- False branch :)
#                           (12) Is 3>=154.74683081171833?: entropy:0.57
#                          ----- True branch :)
#                             The predicted value --> 1.0
#                          ----- False branch :)
#                             The predicted value --> 0.0
#                ----- False branch :)
#                   (8) Is 0>=959.6272?: entropy:0.18
#                  ----- True branch :)
#                     (9) Is 0>=1288.9875326625377?: entropy:0.14
#                    ----- True branch :)
#                       (10) Is 6>=71.19949611985932?: entropy:0.99
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#                    ----- False branch :)
#                       The predicted value --> 0.0
#                  ----- False branch :)
#                     (9) Is 4>=-19.3?: entropy:0.41
#                    ----- True branch :)
#                       (10) Is 5>=177.267?: entropy:0.18
#                      ----- True branch :)
#                         The predicted value --> 0.0
#                      ----- False branch :)
#                         (11) Is 5>=106.72510409083728?: entropy:0.47
#                        ----- True branch :)
#                           (12) Is 3>=64.06120798227556?: entropy:0.92
#                          ----- True branch :)
#                             The predicted value --> 1.0
#                          ----- False branch :)
#                             The predicted value --> 0.0
#                        ----- False branch :)
#                           The predicted value --> 0.0
#                    ----- False branch :)
#                       (10) Is 5>=152.32971422783996?: entropy:0.24
#                      ----- True branch :)
#                         (11) Is 0>=872.0829718551186?: entropy:0.25
#                        ----- True branch :)
#                           The predicted value --> 1.0
#                        ----- False branch :)
#                           (12) Is 3>=198.50681180862242?: entropy:1.00
#                          ----- True branch :)
#                             The predicted value --> 1.0
#                          ----- False branch :)
#                             The predicted value --> 0.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#          ----- False branch :)
#             (5) Is 3>=402.088?: entropy:0.02
#            ----- True branch :)
#               (6) Is 2>=58.451477192780686?: entropy:0.05
#              ----- True branch :)
#                 (7) Is 3>=2246.2?: entropy:0.04
#                ----- True branch :)
#                   The predicted value --> 0.0
#                ----- False branch :)
#                   (8) Is 2>=95.84258497590183?: entropy:0.03
#                  ----- True branch :)
#                     (9) Is 4>=1150.6?: entropy:0.07
#                    ----- True branch :)
#                       The predicted value --> 0.0
#                    ----- False branch :)
#                       (10) Is 6>=91.687?: entropy:0.03
#                      ----- True branch :)
#                         (11) Is 3>=1034.793?: entropy:0.37
#                        ----- True branch :)
#                           The predicted value --> 0.0
#                        ----- False branch :)
#                           The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 1.0
#                  ----- False branch :)
#                     (9) Is 0>=200.1645531416968?: entropy:0.07
#                    ----- True branch :)
#                       (10) Is 0>=829.1868?: entropy:0.05
#                      ----- True branch :)
#                         (11) Is 0>=858.3123815707501?: entropy:0.81
#                        ----- True branch :)
#                           The predicted value --> 1.0
#                        ----- False branch :)
#                           The predicted value --> 0.0
#                      ----- False branch :)
#                         (11) Is 4>=420.4361586888606?: entropy:0.05
#                        ----- True branch :)
#                           The predicted value --> 1.0
#                        ----- False branch :)
#                           (12) Is 2>=94.561?: entropy:0.07
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             (13) Is 6>=82.48?: entropy:0.08
#                            ----- True branch :)
#                               (14) Is 0>=642.8270860792421?: entropy:0.64
#                              ----- True branch :)
#                                 The predicted value --> 1.0
#                              ----- False branch :)
#                                 (15) Is 2>=67.096?: entropy:0.65
#                                ----- True branch :)
#                                   The predicted value --> 0.0
#                                ----- False branch :)
#                                   The predicted value --> 1.0
#                            ----- False branch :)
#                               (14) Is 0>=515.7733?: entropy:0.08
#                              ----- True branch :)
#                                 (15) Is 6>=41.6232274128797?: entropy:0.22
#                                ----- True branch :)
#                                   The predicted value --> 1.0
#                                ----- False branch :)
#                                   (16) Is 0>=690.7865?: entropy:0.24
#                                  ----- True branch :)
#                                     The predicted value --> 0.0
#                                  ----- False branch :)
#                                     (17) Is 0>=561.574431878722?: entropy:0.20
#                                    ----- True branch :)
#                                       (18) Is 6>=14.621298994757879?: entropy:0.50
#                                      ----- True branch :)
#                                         The predicted value --> 1.0
#                                      ----- False branch :)
#                                         The predicted value --> 0.0
#                                    ----- False branch :)
#                                       (18) Is 2>=93.84392994173228?: entropy:0.92
#                                      ----- True branch :)
#                                         The predicted value --> 1.0
#                                      ----- False branch :)
#                                         The predicted value --> 0.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                    ----- False branch :)
#                       The predicted value --> 0.0
#              ----- False branch :)
#                 (7) Is 1>=956.229?: entropy:0.12
#                ----- True branch :)
#                   (8) Is 6>=18.232?: entropy:0.61
#                  ----- True branch :)
#                     The predicted value --> 0.0
#                  ----- False branch :)
#                     (9) Is 2>=27.721?: entropy:0.72
#                    ----- True branch :)
#                       The predicted value --> 1.0
#                    ----- False branch :)
#                       The predicted value --> 0.0
#                ----- False branch :)
#                   (8) Is 0>=667.3811?: entropy:0.16
#                  ----- True branch :)
#                     (9) Is 5>=79.17?: entropy:0.24
#                    ----- True branch :)
#                       The predicted value --> 1.0
#                    ----- False branch :)
#                       The predicted value --> 0.0
#                  ----- False branch :)
#                     (9) Is 4>=300.4500042175139?: entropy:0.58
#                    ----- True branch :)
#                       (10) Is 1>=919.006?: entropy:0.24
#                      ----- True branch :)
#                         The predicted value --> 0.0
#                      ----- False branch :)
#                         The predicted value --> 1.0
#                    ----- False branch :)
#                       (10) Is 3>=653.3210759384531?: entropy:0.59
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#            ----- False branch :)
#               (6) Is 5>=349.301?: entropy:0.02
#              ----- True branch :)
#                 (7) Is 1>=948.1795273213686?: entropy:0.15
#                ----- True branch :)
#                   (8) Is 3>=382.6?: entropy:0.55
#                  ----- True branch :)
#                     The predicted value --> 1.0
#                  ----- False branch :)
#                     (9) Is 0>=47.007?: entropy:0.72
#                    ----- True branch :)
#                       The predicted value --> 0.0
#                    ----- False branch :)
#                       The predicted value --> 1.0
#                ----- False branch :)
#                   (8) Is 5>=360.133?: entropy:0.05
#                  ----- True branch :)
#                     The predicted value --> 0.0
#                  ----- False branch :)
#                     (9) Is 1>=299.4672207586988?: entropy:0.59
#                    ----- True branch :)
#                       The predicted value --> 1.0
#                    ----- False branch :)
#                       The predicted value --> 0.0
#              ----- False branch :)
#                 (7) Is 4>=-199.86822107265192?: entropy:0.01
#                ----- True branch :)
#                   (8) Is 1>=122.81880257392893?: entropy:0.01
#                  ----- True branch :)
#                     (9) Is 6>=2.211?: entropy:0.04
#                    ----- True branch :)
#                       (10) Is 4>=-23.46200080980342?: entropy:0.03
#                      ----- True branch :)
#                         (11) Is 3>=37.4?: entropy:0.03
#                        ----- True branch :)
#                           (12) Is 0>=116.40310224832626?: entropy:0.04
#                          ----- True branch :)
#                             (13) Is 5>=36.963880351873684?: entropy:0.04
#                            ----- True branch :)
#                               (14) Is 5>=81.758?: entropy:0.04
#                              ----- True branch :)
#                                 (15) Is 0>=152.8396?: entropy:0.04
#                                ----- True branch :)
#                                   (16) Is 4>=45.01295334859807?: entropy:0.05
#                                  ----- True branch :)
#                                     (17) Is 5>=333.6816696821903?: entropy:0.04
#                                    ----- True branch :)
#                                       The predicted value --> 1.0
#                                    ----- False branch :)
#                                       (18) Is 4>=268.277?: entropy:0.04
#                                      ----- True branch :)
#                                         (19) Is 1>=822.8642297756761?: entropy:0.70
#                                        ----- True branch :)
#                                           The predicted value --> 1.0
#                                        ----- False branch :)
#                                           The predicted value --> 0.0
#                                      ----- False branch :)
#                                         (19) Is 4>=221.6393479342615?: entropy:0.06
#                                        ----- True branch :)
#                                           The predicted value --> 1.0
#                                        ----- False branch :)
#                                           The predicted value --> 1.0
#                                  ----- False branch :)
#                                     (17) Is 0>=855.5837070403269?: entropy:0.18
#                                    ----- True branch :)
#                                       The predicted value --> 1.0
#                                    ----- False branch :)
#                                       (18) Is 1>=245.06580635174444?: entropy:0.13
#                                      ----- True branch :)
#                                         (19) Is 1>=2812.862252074722?: entropy:0.14
#                                        ----- True branch :)
#                                           The predicted value --> 1.0
#                                        ----- False branch :)
#                                           The predicted value --> 0.0
#                                      ----- False branch :)
#                                         The predicted value --> 0.0
#                                ----- False branch :)
#                                   (16) Is 4>=87.345?: entropy:0.52
#                                  ----- True branch :)
#                                     The predicted value --> 0.0
#                                  ----- False branch :)
#                                     The predicted value --> 1.0
#                              ----- False branch :)
#                                 (15) Is 0>=181.91388845943197?: entropy:0.16
#                                ----- True branch :)
#                                   (16) Is 3>=335.968?: entropy:0.10
#                                  ----- True branch :)
#                                     The predicted value --> 0.0
#                                  ----- False branch :)
#                                     (17) Is 5>=44.61682804251994?: entropy:0.12
#                                    ----- True branch :)
#                                       (18) Is 2>=9.571?: entropy:0.07
#                                      ----- True branch :)
#                                         (19) Is 0>=649.2641?: entropy:0.08
#                                        ----- True branch :)
#                                           The predicted value --> 0.0
#                                        ----- False branch :)
#                                           The predicted value --> 1.0
#                                      ----- False branch :)
#                                         (19) Is 2>=6.63?: entropy:1.00
#                                        ----- True branch :)
#                                           The predicted value --> 0.0
#                                        ----- False branch :)
#                                           The predicted value --> 1.0
#                                    ----- False branch :)
#                                       (18) Is 3>=230.84839073609942?: entropy:1.00
#                                      ----- True branch :)
#                                         The predicted value --> 1.0
#                                      ----- False branch :)
#                                         The predicted value --> 0.0
#                                ----- False branch :)
#                                   The predicted value --> 0.0
#                            ----- False branch :)
#                               The predicted value --> 0.0
#                          ----- False branch :)
#                             (13) Is 4>=2.789?: entropy:0.47
#                            ----- True branch :)
#                               The predicted value --> 0.0
#                            ----- False branch :)
#                               (14) Is 3>=99.019?: entropy:0.89
#                              ----- True branch :)
#                                 The predicted value --> 0.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                        ----- False branch :)
#                           (12) Is 0>=553.5356?: entropy:0.16
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             (13) Is 0>=435.43870805383244?: entropy:0.13
#                            ----- True branch :)
#                               (14) Is 6>=78.908?: entropy:0.13
#                              ----- True branch :)
#                                 The predicted value --> 0.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                            ----- False branch :)
#                               (14) Is 0>=116.626?: entropy:0.32
#                              ----- True branch :)
#                                 (15) Is 2>=7.659?: entropy:0.46
#                                ----- True branch :)
#                                   The predicted value --> 0.0
#                                ----- False branch :)
#                                   (16) Is 6>=24.708468036477647?: entropy:0.34
#                                  ----- True branch :)
#                                     The predicted value --> 1.0
#                                  ----- False branch :)
#                                     (17) Is 0>=425.6065593965867?: entropy:0.99
#                                    ----- True branch :)
#                                       The predicted value --> 1.0
#                                    ----- False branch :)
#                                       The predicted value --> 0.0
#                              ----- False branch :)
#                                 (15) Is 2>=6.944505404756126?: entropy:0.33
#                                ----- True branch :)
#                                   The predicted value --> 1.0
#                                ----- False branch :)
#                                   The predicted value --> 0.0
#                      ----- False branch :)
#                         (11) Is 1>=393.47775597634484?: entropy:0.21
#                        ----- True branch :)
#                           (12) Is 3>=265.334?: entropy:0.96
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             The predicted value --> 1.0
#                        ----- False branch :)
#                           (12) Is 3>=1.357?: entropy:0.24
#                          ----- True branch :)
#                             (13) Is 0>=438.9303478424014?: entropy:0.10
#                            ----- True branch :)
#                               (14) Is 0>=532.2599?: entropy:0.81
#                              ----- True branch :)
#                                 The predicted value --> 0.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                            ----- False branch :)
#                               The predicted value --> 0.0
#                          ----- False branch :)
#                             The predicted value --> 1.0
#                    ----- False branch :)
#                       (10) Is 4>=-56.2?: entropy:0.07
#                      ----- True branch :)
#                         (11) Is 3>=65.45385886321303?: entropy:0.07
#                        ----- True branch :)
#                           (12) Is 2>=14.039?: entropy:0.08
#                          ----- True branch :)
#                             (13) Is 1>=233.38?: entropy:0.18
#                            ----- True branch :)
#                               (14) Is 5>=80.192?: entropy:0.15
#                              ----- True branch :)
#                                 (15) Is 6>=-0.5469441826112913?: entropy:0.46
#                                ----- True branch :)
#                                   (16) Is 3>=198.995?: entropy:0.54
#                                  ----- True branch :)
#                                     The predicted value --> 0.0
#                                  ----- False branch :)
#                                     The predicted value --> 1.0
#                                ----- False branch :)
#                                   (16) Is 2>=55.286414731770485?: entropy:0.54
#                                  ----- True branch :)
#                                     The predicted value --> 1.0
#                                  ----- False branch :)
#                                     The predicted value --> 0.0
#                              ----- False branch :)
#                                 (15) Is 0>=166.29119974860174?: entropy:0.18
#                                ----- True branch :)
#                                   The predicted value --> 1.0
#                                ----- False branch :)
#                                   (16) Is 0>=29.091?: entropy:0.92
#                                  ----- True branch :)
#                                     The predicted value --> 0.0
#                                  ----- False branch :)
#                                     The predicted value --> 1.0
#                            ----- False branch :)
#                               The predicted value --> 0.0
#                          ----- False branch :)
#                             (13) Is 5>=85.40781791734653?: entropy:0.09
#                            ----- True branch :)
#                               The predicted value --> 1.0
#                            ----- False branch :)
#                               (14) Is 4>=-2.24?: entropy:0.29
#                              ----- True branch :)
#                                 (15) Is 0>=53.977?: entropy:0.62
#                                ----- True branch :)
#                                   The predicted value --> 0.0
#                                ----- False branch :)
#                                   (16) Is 1>=165.07165936005447?: entropy:0.59
#                                  ----- True branch :)
#                                     The predicted value --> 1.0
#                                  ----- False branch :)
#                                     The predicted value --> 0.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#                        ----- False branch :)
#                           (12) Is 1>=207.266?: entropy:0.21
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             (13) Is 1>=145.8418756044174?: entropy:0.31
#                            ----- True branch :)
#                               (14) Is 3>=8.96473456882062?: entropy:0.59
#                              ----- True branch :)
#                                 The predicted value --> 1.0
#                              ----- False branch :)
#                                 The predicted value --> 0.0
#                            ----- False branch :)
#                               (14) Is 0>=519.0414787978127?: entropy:0.28
#                              ----- True branch :)
#                                 The predicted value --> 1.0
#                              ----- False branch :)
#                                 (15) Is 5>=60.416?: entropy:0.54
#                                ----- True branch :)
#                                   The predicted value --> 0.0
#                                ----- False branch :)
#                                   The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#                  ----- False branch :)
#                     (9) Is 5>=6.161?: entropy:0.01
#                    ----- True branch :)
#                       (10) Is 1>=13.700954941479448?: entropy:0.02
#                      ----- True branch :)
#                         (11) Is 0>=14.2656?: entropy:0.02
#                        ----- True branch :)
#                           (12) Is 0>=839.5077437335648?: entropy:0.02
#                          ----- True branch :)
#                             The predicted value --> 1.0
#                          ----- False branch :)
#                             (13) Is 6>=16.727?: entropy:0.03
#                            ----- True branch :)
#                               (14) Is 1>=80.05274815327655?: entropy:0.17
#                              ----- True branch :)
#                                 (15) Is 3>=27.57?: entropy:0.22
#                                ----- True branch :)
#                                   The predicted value --> 0.0
#                                ----- False branch :)
#                                   (16) Is 6>=32.504?: entropy:0.21
#                                  ----- True branch :)
#                                     The predicted value --> 0.0
#                                  ----- False branch :)
#                                     (17) Is 2>=8.298966872301978?: entropy:0.25
#                                    ----- True branch :)
#                                       (18) Is 3>=1.553?: entropy:0.33
#                                      ----- True branch :)
#                                         (19) Is 1>=88.48877895458037?: entropy:0.30
#                                        ----- True branch :)
#                                           The predicted value --> 1.0
#                                        ----- False branch :)
#                                           The predicted value --> 0.0
#                                      ----- False branch :)
# ...
#                           The predicted value --> 0.0
#                        ----- False branch :)
#                           The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 1.0
#                    ----- False branch :)
#                       The predicted value --> 0.0
#                  ----- False branch :)
#                     (9) Is 0>=436.7958?: entropy:0.92
#                    ----- True branch :)
#                       The predicted value --> 0.0
#                    ----- False branch :)
#                       The predicted value --> 1.0
#                ----- False branch :)
#                   (8) Is 0>=843.7492924354525?: entropy:0.08
#                  ----- True branch :)
#                     (9) Is 0>=1068.957?: entropy:0.27
#                    ----- True branch :)
#                       The predicted value --> 0.0
#                    ----- False branch :)
#                       (10) Is 1>=61.239?: entropy:0.23
#                      ----- True branch :)
#                         The predicted value --> 0.0
#                      ----- False branch :)
#                         The predicted value --> 1.0
#                  ----- False branch :)
#                     (9) Is 6>=-3.809?: entropy:0.10
#                    ----- True branch :)
#                       (10) Is 4>=-13.612766928802142?: entropy:0.04
#                      ----- True branch :)
#                         (11) Is 1>=3.829?: entropy:0.59
#                        ----- True branch :)
#                           The predicted value --> 0.0
#                        ----- False branch :)
#                           The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#                    ----- False branch :)
#                       (10) Is 5>=77.264?: entropy:0.04
#                      ----- True branch :)
#                         (11) Is 1>=79.87907600824315?: entropy:0.19
#                        ----- True branch :)
#                           (12) Is 0>=522.4517?: entropy:1.00
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             The predicted value --> 1.0
#                        ----- False branch :)
#                           The predicted value --> 0.0
#                      ----- False branch :)
#                         (11) Is 4>=-365.217?: entropy:0.03
#                        ----- True branch :)
#                           (12) Is 0>=89.326?: entropy:0.05
#                          ----- True branch :)
#                             (13) Is 4>=-53.067?: entropy:0.14
#                            ----- True branch :)
#                               (14) Is 1>=5.332?: entropy:0.15
#                              ----- True branch :)
#                                 (15) Is 0>=89.9505?: entropy:0.40
#                                ----- True branch :)
#                                   (16) Is 5>=63.153891140863145?: entropy:0.28
#                                  ----- True branch :)
#                                     (17) Is 0>=258.04450030353786?: entropy:0.81
#                                    ----- True branch :)
#                                       The predicted value --> 1.0
#                                    ----- False branch :)
#                                       The predicted value --> 0.0
#                                  ----- False branch :)
#                                     (17) Is 0>=90.594?: entropy:0.15
#                                    ----- True branch :)
#                                       The predicted value --> 0.0
#                                    ----- False branch :)
#                                       (18) Is 0>=90.40810171125135?: entropy:0.92
#                                      ----- True branch :)
#                                         The predicted value --> 1.0
#                                      ----- False branch :)
#                                         The predicted value --> 0.0
#                                ----- False branch :)
#                                   The predicted value --> 1.0
#                              ----- False branch :)
#                                 (15) Is 2>=0.126?: entropy:0.30
#                                ----- True branch :)
#                                   (16) Is 0>=346.5825?: entropy:0.15
#                                  ----- True branch :)
#                                     The predicted value --> 0.0
#                                  ----- False branch :)
#                                     (17) Is 5>=62.939?: entropy:0.09
#                                    ----- True branch :)
#                                       The predicted value --> 0.0
#                                    ----- False branch :)
#                                       (18) Is 6>=-18.489?: entropy:0.11
#                                      ----- True branch :)
#                                         (19) Is 2>=1.863?: entropy:0.08
#                                        ----- True branch :)
#                                           The predicted value --> 1.0
#                                        ----- False branch :)
#                                           The predicted value --> 1.0
#                                      ----- False branch :)
#                                         The predicted value --> 0.0
#                                ----- False branch :)
#                                   The predicted value --> 0.0
#                            ----- False branch :)
#                               (14) Is 1>=12.193?: entropy:0.14
#                              ----- True branch :)
#                                 (15) Is 6>=-39.005?: entropy:0.17
#                                ----- True branch :)
#                                   (16) Is 6>=-34.785?: entropy:0.40
#                                  ----- True branch :)
#                                     (17) Is 2>=4.44?: entropy:0.26
#                                    ----- True branch :)
#                                       The predicted value --> 0.0
#                                    ----- False branch :)
#                                       (18) Is 0>=434.65404444392743?: entropy:0.32
#                                      ----- True branch :)
#                                         The predicted value --> 1.0
#                                      ----- False branch :)
#                                         (19) Is 6>=-28.623?: entropy:0.56
#                                        ----- True branch :)
#                                           The predicted value --> 0.0
#                                        ----- False branch :)
#                                           The predicted value --> 1.0
#                                  ----- False branch :)
#                                     The predicted value --> 1.0
#                                ----- False branch :)
#                                   The predicted value --> 0.0
#                              ----- False branch :)
#                                 (15) Is 2>=0.473?: entropy:0.08
#                                ----- True branch :)
#                                   The predicted value --> 0.0
#                                ----- False branch :)
#                                   (16) Is 2>=0.375?: entropy:0.59
#                                  ----- True branch :)
#                                     The predicted value --> 1.0
#                                  ----- False branch :)
#                                     The predicted value --> 0.0
#                          ----- False branch :)
#                             (13) Is 4>=-172.677?: entropy:0.22
#                            ----- True branch :)
#                               (14) Is 6>=-3.818?: entropy:0.07
#                              ----- True branch :)
#                                 The predicted value --> 1.0
#                              ----- False branch :)
#                                 (15) Is 2>=2.512?: entropy:0.07
#                                ----- True branch :)
#                                   (16) Is 2>=2.927?: entropy:0.24
#                                  ----- True branch :)
#                                     (17) Is 5>=21.174?: entropy:0.25
#                                    ----- True branch :)
#                                       The predicted value --> 0.0
#                                    ----- False branch :)
#                                       (18) Is 0>=55.629?: entropy:1.00
#                                      ----- True branch :)
#                                         The predicted value --> 0.0
#                                      ----- False branch :)
#                                         The predicted value --> 1.0
#                                  ----- False branch :)
#                                     The predicted value --> 1.0
#                                ----- False branch :)
#                                   The predicted value --> 0.0
#                            ----- False branch :)
#                               (14) Is 4>=-199.464?: entropy:0.47
#                              ----- True branch :)
#                                 (15) Is 1>=8.372?: entropy:0.21
#                                ----- True branch :)
#                                   (16) Is 6>=-6.887?: entropy:0.34
#                                  ----- True branch :)
#                                     The predicted value --> 0.0
#                                  ----- False branch :)
#                                     The predicted value --> 1.0
#                                ----- False branch :)
#                                   The predicted value --> 0.0
#                              ----- False branch :)
#                                 (15) Is 2>=1.22?: entropy:0.24
#                                ----- True branch :)
#                                   The predicted value --> 0.0
#                                ----- False branch :)
#                                   (16) Is 1>=9.238?: entropy:0.97
#                                  ----- True branch :)
#                                     The predicted value --> 1.0
#                                  ----- False branch :)
#                                     The predicted value --> 0.0
#                        ----- False branch :)
#                           (12) Is 0>=105.8746?: entropy:0.52
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             (13) Is 1>=613.698?: entropy:0.18
#                            ----- True branch :)
#                               The predicted value --> 0.0
#                            ----- False branch :)
#                               (14) Is 6>=-4.289?: entropy:0.29
#                              ----- True branch :)
#                                 The predicted value --> 0.0
#                              ----- False branch :)
#                                 The predicted value --> 1.0
#              ----- False branch :)
#                 (7) Is 5>=3.103?: entropy:0.08
#                ----- True branch :)
#                   (8) Is 1>=229.34?: entropy:0.04
#                  ----- True branch :)
#                     (9) Is 0>=11.9251?: entropy:0.47
#                    ----- True branch :)
#                       (10) Is 5>=141.397?: entropy:0.92
#                      ----- True branch :)
#                         The predicted value --> 0.0
#                      ----- False branch :)
#                         The predicted value --> 1.0
#                    ----- False branch :)
#                       The predicted value --> 0.0
#                  ----- False branch :)
#                     (9) Is 2>=0.231?: entropy:0.01
#                    ----- True branch :)
#                       The predicted value --> 0.0
#                    ----- False branch :)
#                       (10) Is 2>=0.229?: entropy:0.17
#                      ----- True branch :)
#                         The predicted value --> 1.0
#                      ----- False branch :)
#                         The predicted value --> 0.0
#                ----- False branch :)
#                   (8) Is 6>=5.18940280036217?: entropy:0.13
#                  ----- True branch :)
#                     The predicted value --> 1.0
#                  ----- False branch :)
#                     (9) Is 0>=9.6446?: entropy:0.06
#                    ----- True branch :)
#                       (10) Is 0>=13.6777?: entropy:0.36
#                      ----- True branch :)
#                         (11) Is 6>=-14.626?: entropy:0.09
#                        ----- True branch :)
#                           The predicted value --> 0.0
#                        ----- False branch :)
#                           (12) Is 0>=19.3979?: entropy:0.81
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             The predicted value --> 1.0
#                      ----- False branch :)
#                         (11) Is 4>=-33.483?: entropy:0.23
#                        ----- True branch :)
#                           (12) Is 2>=0.11091623937822813?: entropy:0.37
#                          ----- True branch :)
#                             The predicted value --> 1.0
#                          ----- False branch :)
#                             (13) Is 6>=-1.7374874479027391?: entropy:0.59
#                            ----- True branch :)
#                               (14) Is 1>=0.226?: entropy:0.72
#                              ----- True branch :)
#                                 The predicted value --> 1.0
#                              ----- False branch :)
#                                 The predicted value --> 0.0
#                            ----- False branch :)
#                               The predicted value --> 0.0
#                        ----- False branch :)
#                           (12) Is 4>=-86.761?: entropy:0.59
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             The predicted value --> 1.0
#                    ----- False branch :)
#                       (10) Is 4>=-86.531?: entropy:0.13
#                      ----- True branch :)
#                         (11) Is 4>=-12.682?: entropy:0.07
#                        ----- True branch :)
#                           (12) Is 0>=1.3766?: entropy:0.92
#                          ----- True branch :)
#                             The predicted value --> 0.0
#                          ----- False branch :)
#                             The predicted value --> 1.0
#                        ----- False branch :)
#                           The predicted value --> 0.0
#                      ----- False branch :)
#                         (11) Is 4>=-87.011?: entropy:0.64
#                        ----- True branch :)
#                           The predicted value --> 1.0
#                        ----- False branch :)
#                           (12) Is 2>=1.763?: entropy:0.41
#                          ----- True branch :)
#                             The predicted value --> 1.0
#                          ----- False branch :)
#                             The predicted value --> 0.0
#    ----- False branch :)
#       (2) Is 4>=-9.149?: entropy:0.03
#      ----- True branch :)
#         The predicted value --> 0.0
#      ----- False branch :)
#         (3) Is 4>=-9.362?: entropy:0.12
#        ----- True branch :)
#           The predicted value --> 1.0
#        ----- False branch :)
#           (4) Is 1>=0.114?: entropy:0.12
#          ----- True branch :)
#             The predicted value --> 0.0
#          ----- False branch :)
#             (5) Is 0>=5.3336?: entropy:1.00
#            ----- True branch :)
#               The predicted value --> 0.0
#            ----- False branch :)
#               The predicted value --> 1.0

# %%
from sklearn.metrics import accuracy_score, f1_score
score = accuracy_score(y_test, y_pred)
print("Accuracy:", score)
score = f1_score(y_test, y_pred)
print("F1_score:", score)
# Out:
# Accuracy: 0.7697452229299363
# F1_score: 0.1278648974668275

# %%
def predict(model):
    model.fit(X_train, y_train)
    model.predict(X_test)
    print(classification_report(y_true=y_test, y_pred=model.predict(X_test)))

# %%
predict(tree)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87      2914
#            1       0.09      0.23      0.13       226
#
#     accuracy                           0.77      3140
#    macro avg       0.51      0.52      0.50      3140
# weighted avg       0.87      0.77      0.81      3140

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(
    cm,
    annot=True,
    fmt="g",
    xticklabels=["Alive", "Dead"],
    yticklabels=["Alive", "Dead"],
)
plt.ylabel("Actual", fontsize=13)
plt.title("Confusion Matrix", fontsize=17, pad=20)
plt.gca().xaxis.set_label_position("top")
plt.xlabel("Prediction", fontsize=13)
plt.gca().xaxis.tick_top()

plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, "Prediction", ha="center", fontsize=13)
plt.show()

# %%
# ROC & AUC
# from sklearn.metrics import roc_curve, roc_auc_score
# import matplotlib.pyplot as plt

# Get probabilities (or scores)
y_pred_proba = tree.predict_proba(X_test)

# Compute FPR, TPR, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Compute AUC
auc_score = roc_auc_score(y_test, y_pred_proba)
print(f"AUC: {auc_score:.4f}")

# Plot ROC curve
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Tree Classifier (from Scratch)')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC: 0.5229

# %%
from sklearn.tree import DecisionTreeClassifier
tree_sk = DecisionTreeClassifier(
    criterion = "entropy",
max_depth= 20,
min_samples_leaf = 1,
min_samples_split= 2,
)
tree_sk.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=20)

# %%
y_t_pred = tree_sk.predict(X_test)
accuracy_score(y_test, y_t_pred)
# Out:
# 0.7681528662420383

# %%
f1_score(y_test, y_t_pred)
# Out:
# 0.13126491646778043

# %%
confusion_matrix(y_test, y_t_pred)
# Out:
# array([[2357,  557],
#        [ 171,   55]])

# %%
from sklearn.tree import export_graphviz
from graphviz import Source

import os
PROJECT_ROOT_DIR = "."
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "tree_images")
os.makedirs(IMAGES_PATH, exist_ok=True)

export_graphviz(
    tree_sk, # Our model learnt
    out_file = os.path.join(IMAGES_PATH, "bankruptcy.dot"),
    feature_names = X.columns.tolist(),
    class_names = y.unique().astype(str).tolist(),
    rounded = True,
    filled = True
)
Source.from_file(os.path.join(IMAGES_PATH, "bankruptcy.dot"))
